# %% [markdown]
# # **Import the dataset**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name= tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at:{}'.format(device_name))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Found GPU at:/device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/drive')

from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import re
import random
import glob
import json


path= '/content/drive/MyDrive/nlp hw6/dialogues/*.txt'

# !pwd
path_to_mount = '/content/drive/My Drive/hw6/'
# Out:
# Mounted at /content/drive
# /content

# %% [markdown]
# # **Preproccesing**

# %%
list_of_files = glob.glob(path)
print(list_of_files[1]) # Visualize the first 1
print(len(list_of_files)) # 47

# Parsing
list_of_dicts = [] # Init

# Loop for each file
for filename in list_of_files:
  with open(filename) as f:
      for line in f: # Loop for each line (inside each file)
          list_of_dicts.append(json.loads(line)) # insert in a dictionary


# Visualize the dictionaries
print(list_of_dicts[0])
print(list_of_dicts[1].keys)
print(list_of_dicts[332])
print(list_of_dicts[:3])


#Create a new dict containing only useful data
new_list_of_dicts = [] 

for old_dict in list_of_dicts:
  foodict = {k: v for k, v in old_dict.items() if (k == 'turns')} 
  new_list_of_dicts.append(foodict)

print(len(new_list_of_dicts))

# Just to be sure we don't make bad use of the old variable,
# we will make the old dict equal to the new one.
# In the end, they are all the same.
list_of_dicts = []
list_of_dicts = new_list_of_dicts 

print(list_of_dicts[4390])
# Out:
# /content/drive/MyDrive/nlp hw6/dialogues/MAKE_RESTAURANT_RESERVATIONS.txt
# 47
# {'id': '769feae6', 'user_id': '19b006ed', 'bot_id': '2ede825b', 'domain': 'EVENT_RESERVE', 'task_id': '4dfb7939', 'turns': ['Hello how may I help you?', 'Could you help me with reservations?', 'Sure, I can help with reservations. What would you like to reserve?', "Find me a theater in my area that's performing Shakespeare", 'The Johnson theater is located 1.5 miles from your location and is performing Hamlet on the 12th. Would you like to reserve seating?', "Sure, that sounds great! I'd like 3 tickets for that show on the 12th please", "I'm sorry, it looks like all the seats for the 12th have just filled. Would you be interested in the show on the 13th?", 'Yes, I would', 'Alright. I will reserve 3 tickets for Hamlet at Johnson theater for June 13th at 8 PM. Is that OK?', "Yep, that's great Thanks for the help!", 'Your reservations have been made.']}
# <built-in method keys of dict object at 0x7faa793d53c0>
# {'id': '32edaeac', 'user_id': 'b72a942e', 'bot_id': '1932eb09', 'domain': 'EVENT_RESERVE', 'task_id': 'cc800c4c', 'turns': ['Hello how may I help you?', 'I am looking for tickets to a football game', 'Ok, which game?', 'Bears vs Giants - this Sunday', 'How many tickets?', 'I will need 5 of them', 'Do they have to be together?', 'Preferably, yes', 'I have 5 seats in section 26a', 'Great. I will take them!', 'Perfect']}
# [{'id': '769feae6', 'user_id': '19b006ed', 'bot_id': '2ede825b', 'domain': 'EVENT_RESERVE', 'task_id': '4dfb7939', 'turns': ['Hello how may I help you?', 'Could you help me with reservations?', 'Sure, I can help with reservations. What would you like to reserve?', "Find me a theater in my area that's performing Shakespeare", 'The Johnson theater is located 1.5 miles from your location and is performing Hamlet on the 12th. Would you like to reserve seating?', "Sure, that sounds great! I'd like 3 tickets for that show on the 12th please", "I'm sorry, it looks like all the seats for the 12th have just filled. Would you be interested in the show on the 13th?", 'Yes, I would', 'Alright. I will reserve 3 tickets for Hamlet at Johnson theater for June 13th at 8 PM. Is that OK?', "Yep, that's great Thanks for the help!", 'Your reservations have been made.']}, {'id': 'a63fb3ac', 'user_id': '133024bc', 'bot_id': '46fe62d7', 'domain': 'EVENT_RESERVE', 'task_id': 'cc800c4c', 'turns': ['Hello how may I help you?', 'Can you help me make a reservation', 'Certainly, I can help with that. Where would you like to make a reservation?', 'I need five tickets to the Eagles game this Sunday please', 'Ok, five tickets to the eagles game. What is your budget?', 'Can I have the cheapest tickets available that are all seated together?', 'Ok, let me check. I have five tickets in Row H. Will that work?', "Sure, what's the total price?", 'Total price for all tickets will be 250 dollars. How would you like to pay for that?', 'My credit card on file please', "Great! You're all set. Enjoy the game", 'Thanks']}, {'id': '5ca03afc', 'user_id': 'e0fc18e3', 'bot_id': 'aad13efa', 'domain': 'EVENT_RESERVE', 'task_id': '4dfb7939', 'turns': ['Hello how may I help you?', 'I would like seats to the Lion king', 'For what date?', 'tonight', 'Sorry, there are no seats available tonight', 'how about Sunday afternoon', 'None then either. The next available date is July 15th', 'Dang Ok I will take it for 5 seats', 'Ok. How would you like to pay', 'CC on file', 'Ok You have five seats reserved for Lion King on July 15th']}]
# 37884
# {'turns': ['Hello how may I help you?', "i'd like to know if i have any late fees", 'what is your name?', 'david jones', 'you have $5 in late fees', 'ok, can i pay them off right now?', 'yes. cash or credit?', "i'd like to use my visa card", 'ok what is last 2 number?', '78', 'paid']}

# %%
# Init matrices
questions = []
answers = []

# We assume that the first answer by the bot (aka "Hello, how may I help you?") 
# is returned after a user greeting.
# This is used in order to ensure that the dataset will be even 
# and each question is paired with an answer.
# That's why we create a mini random catalog 
# of artificial 'ghost' user greetings.
matrix_greetings = ["Hey", "Hi"]

# A similar situation happens in the corner case 
# when the last sentence is from the user.
# As said, each sentence from the user should be paired
# with a sentence from the bot.
# That's why we will in this case add an artificial one.
matrix_byes = ["Ok", "Okie", "Bye"]

# For each dictionary in the list
for dictionary in list_of_dicts:
  matrix_QA = dictionary['turns']
  
  # Append a first random greeting, as explained above
  questions.append(random.choice(matrix_greetings))
    
  # In order to split the QAs to 2 matrices (questions & answers),
  # we will use a flag to indicate if the sentence 
  # is given from the bot or from the user
  bot_flag = True # Init

  # For each Q/A in the matrix
  for sentence in matrix_QA:

    if bot_flag == True:
      answers.append(sentence) # Used for bot's answers
      bot_flag = False # Switch
      continue
    else:
      questions.append(sentence) # Used for user's questions
      bot_flag = True # Switch
      continue

  # The last loop (ideally) ends with a bot's answer,
  # thus making bot_flag equal to False.
  # Although, with data visualization and exploring,
  # we can see that this does not happen all the time.

  # Corner case: If the last answers was from the user, 
  # then we need to add one artificial 'ghost' response 
  # from the bot to make the dataset even.
  if bot_flag == True: 
    answers.append(random.choice(matrix_byes))

# %% [markdown]
# #  **Vocabulary**

# %%
sorted_ques= []
sorted_ans=[]
for i in range(len(questions)):
  if len(questions[i]) < 20: #or smaller (13)
    sorted_ques.append(questions[i])
    sorted_ans.append(answers[i])


import re
def clean_text(txt):
  txt= txt.lower()
  txt= re.sub(r"i'm","i am", txt)
  txt= re.sub(r"he's","he is", txt)
  txt= re.sub(r"she's","she is", txt)
  txt= re.sub(r"he's","he is", txt)
  txt= re.sub(r"that's","that is", txt)
  txt= re.sub(r"what's","what is", txt)
  txt= re.sub(r"where's","where is", txt)
  txt= re.sub(r"\'ll"," will", txt)
  txt= re.sub(r"\'ve"," have", txt)
  txt= re.sub(r"\'re"," are", txt)
  txt= re.sub(r"\'d"," would", txt)
  txt= re.sub(r"won't","will not", txt)
  txt= re.sub(r"[^\w\s]","", txt)
  return txt


clean_ques= []
clean_ans= []

for line in sorted_ques:
  clean_ques.append(clean_text(line))

for line in sorted_ans:
  clean_ans.append(clean_text(line))



for i in range(len(clean_ans)):
  clean_ans[i]=' '.join(clean_ans[i].split()[:17])  #or smaller (11)



#clean_ans= clean_ans[:10000]
#clean_ques = clean_ques[:10000]

# %%
print(len(clean_ans))
# Out:
# 95141

# %%
word2count= {}
for line in clean_ques:
  for word in line.split():
    if word not in word2count:
      word2count[word] =1
    else:
      word2count[word] +=1
for line in clean_ans:
  for word in line.split():
    if word not in word2count:
      word2count[word] =1
    else:
      word2count[word] +=1

thresh= 5
vocab={}
word_num = 0
for word, count in word2count.items():
  if count >= thresh:
    vocab[word] = word_num
    word_num +=1


for i in range(len(clean_ans)):
  clean_ans[i] = '<SOS> ' + clean_ans[i] +' <EOS>'

tokens= ['<PAD>','<EOS>','<OUT>','<SOS>']
x=len(vocab)
for token in tokens:
  vocab[token]=x
  x+=1

# %%
print(len(clean_ans))
print(len(clean_ques))
print(clean_ans[4])
print(clean_ques[4])
# Out:
# 95141
# 95141
# <SOS> hello how may i help you <EOS>
# hi

# %%
print(clean_ques[100:900])
# Out:
# ['i need some help', 'how much is it', 'hi', 'try saturday', 'hi', 'a circus tent', 'hey', 'tomorrow', 'the big theatre', 'hey', 'football on sunday', 'can you reserve me', '5pcspls', 'hey', 'how about the 7th', 'dope nope', 'hi', '444 pedro avenue', 'anytwon usa', 'hi', 'hey', 'how much is it', 'no thank you', 'hey', 'ok then', 'hey', 'ouch that is a lot', 'hey', 'hey', 'bot', 'the tn theater', '8', 'yes book it', 'johnny b cool', 'hi', 'hi hi', 'yeah sure', 'how can i help you', 'hey', 'the giants game', 'yea preferably', 'credit card', 'that is all thanks', 'hey', 'that is all thanks', 'hey', 'hey', 'how much is it ', 'hey', 'how much is that', 'thanks', 'hi', 'how much', 'thank you', 'hi', 'hey', 'what are the name ', 'how bout bachmans', 'ok bye', 'hey', 'making reservations', 'hladik theater', 'yes', 'harry potter', 'hey', 'great thanks', 'hi', 'yes please', 'oh im surprised', 'hi', 'at the theatre', '9', 'tomorrow', 'the ex pres threare', 'hey', 'how much is it', 'hi', 'how much is it', 'what no way', 'thank you', 'hey', 'i need 2', 'great thank you', 'hi', 'i need 5', 'bears vs esgles', 'eagles yes please', 'hey', 'any suggestions', 'thanks', 'hey', 'hi', 'i have concern', 'i can manage', 'hi', 'hey', 'ballet', 'to bad', 'hey', 'circus tent', 'yes', 'how much is it', 'hey', 'june 30th', 'hi', 'hi
ways': 217, '6': 218, 'packers': 219, 'sad': 220, 'houston': 221, 'get': 222, 'new': 223, 'york': 224, 'say': 225, '100': 226, 'downtown': 227, 'course': 228, 'september': 229, '5th': 230, '1': 231, 'ridiculous': 232, 'info': 233, 'late': 234, 'event': 235, 'kidding': 236, 'two': 237, '6th': 238, 'reservation': 239, 'biggest': 240, 'size': 241, 'deluxe': 242, 'rose': 243, 'many': 244, 'play': 245, 'ordered': 246, 'best': 247, 'noon': 248, 'roger': 249, 'local': 250, 'hamilton': 251, 'o': 252, 'king': 253, '28th': 254, '15': 255, 'team': 256, 'adults': 257, 'right': 258, 'pizza': 259, 'hut': 260, 'alrighty': 261, 'assistance': 262, 'main': 263, 'lights': 264, 'lion': 265, 'print': 266, 'home': 267, 'mars': 268, 'nyc': 269, 'section': 270, '27': 271, 'march': 272, '29': 273, '2018': 274, 'games': 275, 'chicago': 276, 'spots': 277, 'was': 278, 'be': 279, 'works': 280, 'april': 281, '24th': 282, 'jurassic': 283, 'world': 284, 'lets': 285, 'pax': 286, 'people': 287, 'set': 288, 'why': 289, '8th': 290, '700': 291, 'elmo': 292, 'rocks': 293, 'here': 294, 'buy': 295, 'against': 296, 'california': 297, 'georgia': 298, 'there': 299, 'ty': 300, 'crazy': 301, 'your': 302, 'weekend': 303, 'philadelphia' ...

# %%
vocab['hey']= vocab['<PAD>']
vocab['<PAD>']=0

# %%
#inverse answers dict
inv_vocab= {w:v for v ,w in vocab.items()}

# %%
print(len(vocab))
print(len(inv_vocab))
# Out:
# 3653
# 3653

# %% [markdown]
# # **Creating inputs**

# %%
encoder_input= []
for line in clean_ques:
  lst=[]
  for word in line.split():
    if word not in vocab:
      lst.append(vocab['<OUT>'])
    else:
      lst.append(vocab[word])
  
  encoder_input.append(lst)

decoder_input= []
for line in clean_ans:
  lst=[]
  for word in line.split():
    if word not in vocab:
      lst.append(vocab['<OUT>'])
    else:
      lst.append(vocab[word])
  
  decoder_input.append(lst)
#del(clean_ans,clean_ques,lst,word)

# %%
#print(encoder_input)
print(decoder_input[:100])
print(vocab)
print(inv_vocab)
# Out:
# [[3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 306, 2, 39, 84, 30, 67, 130, 150, 112, 869, 14, 130, 124, 855, 112, 93, 132, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 2401, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 65, 299, 103, 29, 140, 62, 6, 3650], [3652, 48, 34, 119, 12, 140, 2329, 130, 265, 253, 8, 15, 945, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 209, 2, 202, 13, 3651, 92, 17, 83, 2, 11, 34, 3650], [3652, 2, 119, 2329, 21, 140, 41, 270, 2847, 43, 93, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 20, 1496, 3, 34, 153, 13, 67, 130, 3650], [3652, 2, 202, 65, 524, 299, 2848, 38, 140, 62, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 19, 26, 2371, 1116, 1129, 134, 25, 137, 26, 405, 2127, 51, 303, 378, 214, 135, 2849, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 639, 706, 2449, 63, 425, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 37, 25, 26, 76, 22, 126, 255, 130, 21, 706, 3650], [3652, 34, 83, 204, 27, 341, 58, 430, 34, 69, 3650], [3652, 105, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652, 17, 244, 67, 39, 34, 10, 3650], [3652, 20, 270, 39, 34, 279, 3651, 41, 3650], [3652, 306, 3651, 67, 122, 302, 1545, 3650], [3652, 209, 17, 127, 2, 11, 34, 3650], [3652,
'2018': 274, 'games': 275, 'chicago': 276, 'spots': 277, 'was': 278, 'be': 279, 'works': 280, 'april': 281, '24th': 282, 'jurassic': 283, 'world': 284, 'lets': 285, 'pax': 286, 'people': 287, 'set': 288, 'why': 289, '8th': 290, '700': 291, 'elmo': 292, 'rocks': 293, 'here': 294, 'buy': 295, 'against': 296, 'california': 297, 'georgia': 298, 'there': 299, 'ty': 300, 'crazy': 301, 'your': 302, 'weekend': 303, 'philadelph ...
# {3649: 'hey', 1: 'yes', 2: 'i', 3: 'would', 4: 'thanks', 5: 'hi', 6: 'tonight', 7: 'cc', 8: 'on', 9: 'file', 10: 'need', 11: 'help', 12: 'five', 13: 'the', 14: 'theater', 15: 'july', 16: '23rd', 17: 'how', 18: 'about', 19: 'saturday', 20: 'what', 21: '5', 22: 'total', 23: 'sounds', 24: 'good', 25: 'that', 26: 'is', 27: 'it', 28: 'bears', 29: 'no', 30: '3', 31: 'please', 32: 'great', 33: 'thank', 34: 'you', 35: 'today', 36: 'florida', 37: 'okay', 38: 'any', 39: 'will', 40: 'do', 41: 'in', 42: 'middle', 43: 'row', 44: 'did', 45: 'bout', 46: 'far', 47: 'away', 48: 'ok', 49: '4', 50: 'theatre', 51: 'this', 52: 'friday', 53: 'night', 54: 'giants', 55: 'whats', 56: 'price', 57: 'credit', 58: 'card', 59: 'opera', 60: '7pm', 61: '2', 62: 'available', 63: 'go', 64: 'ahead', 65: 'sorry', 66: 'all', 67: 'tickets', 68: 'correct', 69: 'want', 70: '18', 71: 'forget', 72: 'then', 73: 'some', 74: 'much', 75: 'try', 76: 'a', 77: 'circus', 78: 'tent', 79: 'tomorrow', 80: 'big', 81: 'football', 82: 'sunday', 83: 'can', 84: 'reserve', 85: 'me', 86: '7th', 87: 'nope', 88: 'avenue', 89: 'usa', 90: 'ouch', 91: 'lot', 92: 'bot', 93: '8', 94: 'book', 95: 'johnny', 96: 'b', 97: 'cool', 98: 'yeah', 99: 'sure', 100: 'game', 101: 'yea', 102: 'preferably', 103: 'are', 104: 'name', 105: 'bye', 106: 'making', 107: 'reservations', 108: 'harry', 109: 'potter', 110: 'oh', 111: 'im', 112: 'at', 113: '9', 114: 'ex', 115: 'way', 116: 'vs', 117: 'eagles', 118: 'suggestions', 119: 'have', 120: 'concern', 121: 'manage', 122: 'to', 123: 'bad', 124: 'june', 125: '30th', 126: 'of', 127: 'may', 128: '21st', 129: '8pm', 130: 'for', 131: '800', 132: 'pm', 133: 'dang', 134: 'well', 135: 'just', 136: 'anyway', 137: 'movie', 138: '7', 139: 'john', 140: 'seats', 141: 'near', 142: 'thats', 143: 'pls', 144: 'time', 145: 'really', 146: 'monday', 147: '10', 148: 'lay', 149: 'seahawks', 150: 'hamlet', 151: 'take', 152: 'them', 153: 'like', 154: 'house', 155: 'thing', 156: 'yep', 157: 'purchase', 158: 'sundays', 159: 'lower', 160: 'next', 161: 'week', 162: 'asap', 163: 'money', 164: 'object', 165: 'expensive', 166: 'u', 167: 'so', 168: '29th', 169: 'check', 170: '30', 171: 'th', 172: 'alabama', 173: 'problem', 174: 'awesome', 175: 'not', 176: 'an', 177: 'issue', 178: 'broncos', 179: 'and', 180: 'jets', 181: 'perfect', 182: 'nah', 183: 'they', 184: 'outrageous', 185: 'request', 186: 'where', 187: 'atlantis', 188: 'boston', 189: 'finish', 190: 'four', 191: '1200', 192: 'add', 193: 'one', 194: 'more', 195: 'extra', 196: 'large', 197: '730', 198: 'wow', 199: 'ants', 200: 'show', 201: 'fine', 202: 'am', 203: 'willing', 204: 'pay', 205: '23', 206: 'bills', 207: 'patriots', 208: 'wednesday', 209: 'hello', 210: 'seat', 211: 'front', 212: 'seattle', 213: 'cancel', 214: 'its', 215: 'with', 216: 'amazing', 217: 'anyways', 218: '6', 219: 'packers', 220: 'sad', 221: 'houston', 222: 'get', 223: 'new', 224: 'york', 225: 'say', 226: '100', 227: 'downtown', 228: 'course', 229: 'september', 230: '5th', 231: '1', 232: 'ridiculous', 233: 'info', 234: 'late', 235: 'event', 236: 'kidding', 237: 'two', 238: '6th', 239: 'reservation', 240: 'biggest', 241: 'size', 242: 'deluxe', 243: 'rose', 244: 'many', 245: 'play', 246: 'ordered', 247: 'best', 248: 'noon', 249: 'roger', 250: 'local', 251: 'hamilton', 252: 'o', 253: 'king', 254: '28th', 255: '15', 256: 'team', 257: 'adults', 258: 'right', 259: 'pizza', 260: 'hut', 261: 'alrighty', 262: 'assistance', 263: 'main', 264: 'lights', 265: 'lion', 266: 'print', 267: 'home', 268: 'mars', 269: 'nyc', 270: 'section', 271: '27', 272: 'march', 273: '29', 274: '2018', 275: 'games', 276: 'chicago', 277: 'spots', 278: 'was', 279: 'be', 280: 'works', 281: 'april', 282: '24th', 283: 'jurassic', 284: 'world', 285: 'lets', 286: 'pax', 287: 'people', 288: 'set', 289: 'why', 290: '8th', 291: '700', 292: 'elmo', 293: 'rocks', 294: 'here', 295: 'buy', 296: 'against', 297: 'california', 298: 'georgia', 299: 'there', 300: 'ty', 301: 'crazy', 302: 'your', 303: 'weekend', 304: 'phila ...

# %%
from keras.utils import pad_sequences
encoder_input= pad_sequences(encoder_input, 20, padding='post',truncating='post')
decoder_input= pad_sequences(decoder_input, 20, padding='post',truncating='post')

# %%
print(decoder_input)
print(encoder_input)
# Out:
# [[3652  209   17 ...    0    0    0]
#  [3652  306    2 ...  132 3650    0]
#  [3652  209   17 ...    0    0    0]
#  ...
#  [3652  209   17 ...    0    0    0]
#  [3652   26  299 ...    0    0    0]
#  [3652   34  103 ...    0    0    0]]
# [[3649    0    0 ...    0    0    0]
#  [   1    2    3 ...    0    0    0]
#  [3649    0    0 ...    0    0    0]
#  ...
#  [3649    0    0 ...    0    0    0]
#  [  32    0    0 ...    0    0    0]
#  [  29    4    0 ...    0    0    0]]

# %%
decoder_final_output=[]
for i in decoder_input:
  decoder_final_output.append(i[1:])

decoder_final_output= pad_sequences(decoder_final_output,20,padding='post',truncating='post')

# %% [markdown]
# # **Building the Model**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Embedding, LSTM , Input
from tensorflow.keras.utils import to_categorical

# %%
#decoder_final_output = to_categorical(decoder_final_output, len(vocab))  #----> Raises error in ram

# %%
enc_inp= Input(shape=(20,))
dec_inp= Input(shape=(20,))



VOCAB_SIZE= len(vocab)
embed= Embedding(VOCAB_SIZE+1, output_dim=50, 
                 input_length=20,
                 trainable=True)


enc_embed= embed(enc_inp)
enc_lstm= LSTM(512, return_sequences=True, return_state=True)
enc_op , h ,c = enc_lstm(enc_embed)
enc_states= [h,c]

dec_embed= embed(dec_inp)
dec_lstm= LSTM(512, return_sequences=True, return_state=True)
dec_op, _, _ = dec_lstm(dec_embed, initial_state=enc_states)

dense= Dense(VOCAB_SIZE, activation='softmax')
dense_op=dense(dec_op)

model=Model([enc_inp, dec_inp], dense_op)

model.compile(loss='sparse_categorical_crossentropy',metrics=['acc'],optimizer='Adam')

model.fit([encoder_input, decoder_input],decoder_final_output,epochs=50, batch_size=20, validation_split=0.2)
# Out:
# Epoch 1/50
# 3806/3806 [==============================] - 57s 13ms/step - loss: 1.0202 - acc: 0.8293 - val_loss: 0.8349 - val_acc: 0.8574
# Epoch 2/50
# 3806/3806 [==============================] - 48s 13ms/step - loss: 0.7757 - acc: 0.8548 - val_loss: 0.7801 - val_acc: 0.8649
# Epoch 3/50
# 3806/3806 [==============================] - 49s 13ms/step - loss: 0.6934 - acc: 0.8629 - val_loss: 0.7661 - val_acc: 0.8666
# Epoch 4/50
# 3806/3806 [==============================] - 48s 12ms/step - loss: 0.6385 - acc: 0.8680 - val_loss: 0.7707 - val_acc: 0.8669
# Epoch 5/50
# 3806/3806 [==============================] - 48s 12ms/step - loss: 0.5936 - acc: 0.8722 - val_loss: 0.7813 - val_acc: 0.8676
# Epoch 6/50
# 3806/3806 [==============================] - 48s 13ms/step - loss: 0.5544 - acc: 0.8764 - val_loss: 0.7925 - val_acc: 0.8677
# Epoch 7/50
# 3806/3806 [==============================] - 48s 12ms/step - loss: 0.5183 - acc: 0.8811 - val_loss: 0.8153 - val_acc: 0.8668
# Epoch 8/50
# 3806/3806 [==============================] - 48s 13ms/step - loss: 0.4854 - acc: 0.8865 - val_loss: 0.8354 - val_acc: 0.8670
# Epoch 9/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.4565 - acc: 0.8913 - val_loss: 0.8570 - val_acc: 0.8660
# Epoch 10/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.4299 - acc: 0.8965 - val_loss: 0.8801 - val_acc: 0.8654
# Epoch 11/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.4064 - acc: 0.9008 - val_loss: 0.8969 - val_acc: 0.8653
# Epoch 12/50
# 3806/3806 [==============================] - 48s 13ms/step - loss: 0.3849 - acc: 0.9053 - val_loss: 0.9201 - val_acc: 0.8646
# Epoch 13/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.3656 - acc: 0.9093 - val_loss: 0.9446 - val_acc: 0.8639
# Epoch 14/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.3479 - acc: 0.9131 - val_loss: 0.9631 - val_acc: 0.8638
# Epoch 15/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.3325 - acc: 0.9165 - val_loss: 0.9845 - val_acc: 0.8629
# Epoch 16/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.3181 - acc: 0.9196 - val_loss: 1.0040 - val_acc: 0.8624
# Epoch 17/50
# 3806/3806 [==============================] - 48s 13ms/step - loss: 0.3056 - acc: 0.9225 - val_loss: 1.0240 - val_acc: 0.8625
# Epoch 18/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.2939 - acc: 0.9250 - val_loss: 1.0458 - val_acc: 0.8618
# Epoch 19/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.2834 - acc: 0.9276 - val_loss: 1.0668 - val_acc: 0.8614
# Epoch 20/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.2741 - acc: 0.9296 - val_loss: 1.0842 - val_acc: 0.8618
# Epoch 21/50
# 3806/3806 [==============================] - 47s 12ms/step - loss: 0.2654 - acc: 0.9316 - val_loss: 1.1026 - val_acc: 0.8605
# Epoch 22/50
# 3806/3806 [==============================] - 48s 13ms/step - loss: 0
oder_states_inputs = [decoder_state_input_h, decoder_state_input_c]


decoder_outputs, state_h, state_c = dec_lstm(dec_embed , 
                                    initial_state=decoder_states_inputs)


decoder_states = [state_h, state_c]


dec_model = Model([dec_inp]+ decoder_states_inputs,
                                      [decoder_outputs]+ decoder_states)




print("##########################################")
print("#       start chatting ver. 1.0          #")
print("##########################################")


prepro1 = ""
while prepro1 != 'q':
    prepro1  = input("you : ")
    ## prepro1 = "Hello"

    prepro1 = clean_text(prepro1)
    ## prepro1 = "hello"

    prepro = [prepro1]
    ## prepro1 = ["hello"]

    txt = []
    for x in prepro:
        # x = "hello"
        lst = []
        for y in x.split():
            ## y = "hello"
            try:
                lst.append(vocab[y])
                ## vocab['hello'] = 454
            except:
                lst.append(vocab['<OUT>'])
        txt.append(lst)

    ## txt = [[454]]
    txt = pad_sequences(txt, 20, padding='post')

    ## txt = [[454,0,0,0,.........13]]

    stat = enc_model.predict(txt)

    empty_target_seq = np.zeros( ( 1 , 1) )
     ##   empty_target_seq = [0]


    empty_target_seq[0, 0] = vocab['<SOS>']
    ##    empty_target_seq = [255]

    stop_condition = False
    decoded_translation = ''

    while not stop_condition :

        dec_outputs , h, c= dec_model.predict([ empty_target_seq] + stat )
        decoder_concat_input = dense(dec_outputs)
        ## decoder_concat_input = [0.1, 0.2, .4, .0, ...............]

        sampled_word_index = np.argmax( decoder_concat_input[0, -1, :] )
        ## sampled_word_index = [2]

        sampled_word = inv_vocab[sampled_word_index] + ' '

        ## inv_vocab[2] = 'hi'
        ## sampled_word = 'hi '

        if sampled_word != '<EOS> ':
            decoded_translation += sampled_word  

        if sampled_word == '<EOS> ' or len(decoded_translation.split()) > 20:
            stop_condition = True 

        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        ## <SOS> - > hi
        ## hi --> <EOS>
        stat = [h, c]  

    print("chatbot attention : ", decoded_translation )
    print("==============================================")
# Out:
# ##########################################
# #       start chatting ver. 1.0          #
# ##########################################
# you : can i ask you something?
# 1/1 [==============================] - 0s 283ms/step
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (None, 1).
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 16ms/step
# chatbot attention :  yes
# ==============================================
# you : i am intrested abou London
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# chatbot attention :  it is not a style
# ==============================================
# you : how can i go to London?
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# chatbot attention :  you can just get it for 10 more
# ==============================================
# you : can you book me a table for four?
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# chatbot attention :  i am sorry but i am unable to recognize that book
# ==============================================
# you : i mean i want you to make me a reservation
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# chatbot attention :  i am sorry but i am legally obligated for reservations <OUT> for too complicated i am
# ==============================================
# you : can you make a reservation?
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# chatbot attention :  unfortunately but i cant
# ==============================================
# you : what can you do?
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# chatbot attention :  i can help with alarms
# ==============================================
# you : set an alarm for five a.m
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# chatbot attention :  sound or vibrate
# ==============================================
# you : sound
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# chatbot attention :  what sound rooster sound
# ==============================================
# you : whatever you like
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# chatbot attention :  cheers
# ==============================================
# you : bye
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# chatbot attention :  bye
# ==============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-29bb38f8e1ba> in <module>
#      34 prepro1 = ""
#      35 while prepro1 != 'q':
# ---> 36     prepro1  = input("you : ")
#      37     ## prepro1 = "Hello"
#      38
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
